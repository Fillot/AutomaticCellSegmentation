# %% [markdown]
# # Tom's pipeline for automated FISH analysis
#
# v0.1 : semi-automated notebook for automated segmentation of microscopy images
#
# We start by importing all the files and libraries used to run this pipeline.
#
# Requirement:
#     standard:
#         - numpy
#         - os
#         - pathlib
#         - glob
#         - PIL
#         - skimage
#     non-standard:
#         - cellpose

# %%
# custom libraries. 
# The corresponding files (for ex., autosegmentation.py) 
# must be in the same folder as this notebook
import autosegmentation as seg
import sanitize
import readwrite as rw

# %% [markdown]
# To start the processing, enter the path to the folder that contains the images, for the variable root_folder. "exemple_data" is a folder in this folder, containing some microscopy images of p21 FISH & p53 IF combined. If the data isn't in the same directory as the notebook, you have to provide the full path to it.

# %%
root_folder = "/home/tom/Documents/Scientifique/Thesis/Data/27X/271"
rw.prepare_folders(root_folder)

# %% [markdown]
# Then we read all the .tif in the folder, save the splitted channels separately (for FISHQuant) and do the max projections (for Cellpose).

# %%
rw.split_and_project(root_folder, all_tiff = True, red=1, green=2, blue=3)
# Out:
# Processing nutlin_15_MMStack_Pos0.ome.tif
# Processing nutlin_13_MMStack_Pos0.ome.tif
# Processing nutlin_18_MMStack_Pos0.ome.tif
# Processing nutlin_12_MMStack_Pos0.ome.tif
# Processing DMSO_11_MMStack_Pos0.ome.tif
# Processing DMSO_3_MMStack_Pos0.ome.tif
# Processing DMSO_3_MMStack_Pos0.ome.tif
# Processing nutlin_1_MMStack_Pos0.ome.tif
# Processing DMSO_14_MMStack_Pos0.ome.tif
# Processing DMSO_19_MMStack_Pos0.ome.tif
# Processing DMSO_2_MMStack_Pos0.ome.tif
# Processing nutlin_9_MMStack_Pos0.ome.tif
# Processing nutlin_11_MMStack_Pos0.ome.tif
# Processing DMSO_7_MMStack_Pos0.ome.tif
# Processing nutlin_20_MMStack_Pos0.ome.tif
# Processing DMSO_18_MMStack_Pos0.ome.tif
# Processing DMSO_5_MMStack_Pos0.ome.tif
# Processing nutlin_8_MMStack_Pos0.ome.tif
# Processing nutlin_14_MMStack_Pos0.ome.tif
# Processing nutlin_2_MMStack_Pos0.ome.tif
# Processing nutlin_4_MMStack_Pos0.ome.tif
# Processing DMSO_4_MMStack_Pos0.ome.tif
# Processing DMSO_1_MMStack_Pos0.ome.tif
# Processing DMSO_17_MMStack_Pos0.ome.tif
# Processing nutlin_7_MMStack_Pos0.ome.tif
# Processing nutlin_6_MMStack_Pos0.ome.tif
# Processing DMSO_20_MMStack_Pos0.ome.tif
# Processing DMSO_6_MMStack_Pos0.ome.tif
# Processing nutlin_17_MMStack_Pos0.ome.tif
# Processing nutlin_19_MMStack_Pos0.ome.tif
# Processing DMSO_8_MMStack_Pos0.ome.tif
# Processing nutlin_5_MMStack_Pos0.ome.tif
# Processing DMSO_13_MMStack_Pos0.ome.tif
# Processing DMSO_10_MMStack_Pos0.ome.tif
# Processing DMSO_15_MMStack_Pos0.ome.tif
# Processing DMSO_16_MMStack_Pos0.ome.tif
# Processing nutlin_16_MMStack_Pos0.ome.tif
# Processing DMSO_9_MMStack_Pos0.ome.tif
# Processing DMSO_12_MMStack_Pos0.ome.tif
# Processing nutlin_10_MMStack_Pos0.ome.tif

# %% [markdown]
# We use cellpose to generate the outlines on all the max projections. By default the GPU is turned on, which I find not only works much faster, but also leads to less crashes, which is important because Cellpose can crashes without throwing you an error.

# %%
seg.cellpose_outlines(root_folder, 
                  cell_diameter=230, 
                  nucleus_diameter=100, 
                  save_masks=True)
# Out:
# Logging file doesn't exist
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_10_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# /home/tom/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# time spent: running network 0.49s; flow+mask computation 39.12
# estimated masks for 1 image(s) in 39.67 sec
# >>>> TOTAL TIME 39.67 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.41s; flow+mask computation 2.42
# estimated masks for 1 image(s) in 2.86 sec
# >>>> TOTAL TIME 2.86 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_11_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 23.29
# estimated masks for 1 image(s) in 23.57 sec
# >>>> TOTAL TIME 23.57 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.75
# estimated masks for 1 image(s) in 2.03 sec
# >>>> TOTAL TIME 2.03 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_12_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 10.49
# estimated masks for 1 image(s) in 10.78 sec
# >>>> TOTAL TIME 10.78 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.55
# estimated masks for 1 image(s) in 1.83 sec
# >>>> TOTAL TIME 1.83 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_13_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 16.27
# estimated masks for 1 image(s) in 16.54 sec
# >>>> TOTAL TIME 16.54 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.74
# estimated masks for 1 image(s) in 2.04 sec
# >>>> TOTAL TIME 2.04 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_14_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 20.50
# estimated masks for 1 image(s) in 20.80 sec
# >>>> TOTAL TIME 20.80 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 2.36
# estimated masks for 1 image(s) in 2.64 sec
# >>>> TOTAL TIME 2.64 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_15_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 10.00
# estimated masks for 1 image(s) in 10.28 sec
# >>>> TOTAL TIME 10.28 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 2.22
# estimated masks for 1 image(s) in 2.52 sec
# >>>> TOTAL TIME 2.52 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_16_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 5.87
# estimated masks for 1 image(s) in 6.14 sec
# >>>> TOTAL TIME 6.14 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.73
# estimated masks for 1 image(s) in 2.03 sec
# >>>> TOTAL TIME 2.03 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_17_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 8.57
# estimated masks for 1 image(s) in 8.86 sec
# >>>> TOTAL TIME 8.86 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.75
# estimated masks for 1 image(s) in 2.05 sec
# >>>> TOTAL TIME 2.05 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_18_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 10.86
# estimated masks for 1 image(s) in 11.16 sec
# >>>> TOTAL TIME 11.16 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 1.84
# estimated masks for 1 image(s) in 2.12 sec
# >>>> TOTAL TIME 2.12 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_19_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.23s; flow+mask computation 45.09
# estimated masks for 1 image(s) in 45.37 sec
# >>>> TOTAL TIME 45.37 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.92
# estimated masks for 1 image(s) in 2.22 sec
# >>>> TOTAL TIME 2.22 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_1_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 12.17
# estimated masks for 1 image(s) in 12.46 sec
# >>>> TOTAL TIME 12.46 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 2.24
# estimated masks for 1 image(s) in 2.52 sec
# >>>> TOTAL TIME 2.52 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_20_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 46.75
# estimated masks for 1 image(s) in 47.03 sec
# >>>> TOTAL TIME 47.03 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.43
# estimated masks for 1 image(s) in 1.72 sec
# >>>> TOTAL TIME 1.72 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_2_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 21.44
# estimated masks for 1 image(s) in 21.73 sec
# >>>> TOTAL TIME 21.73 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 3.48
# estimated masks for 1 image(s) in 3.76 sec
# >>>> TOTAL TIME 3.76 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_3_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 5.56
# estimated masks for 1 image(s) in 5.86 sec
# >>>> TOTAL TIME 5.86 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.62
# estimated masks for 1 image(s) in 1.91 sec
# >>>> TOTAL TIME 1.91 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_4_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 12.47
# estimated masks for 1 image(s) in 12.75 sec
# >>>> TOTAL TIME 12.75 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.33s; flow+mask computation 1.71
# estimated masks for 1 image(s) in 2.07 sec
# >>>> TOTAL TIME 2.07 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_5_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 19.05
# estimated masks for 1 image(s) in 19.34 sec
# >>>> TOTAL TIME 19.34 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.42s; flow+mask computation 2.24
# estimated masks for 1 image(s) in 2.69 sec
# >>>> TOTAL TIME 2.69 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_6_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.44s; flow+mask computation 5.73
# estimated masks for 1 image(s) in 6.22 sec
# >>>> TOTAL TIME 6.22 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 1.67
# estimated masks for 1 image(s) in 1.98 sec
# >>>> TOTAL TIME 1.98 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_7_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 17.35
# estimated masks for 1 image(s) in 17.66 sec
# >>>> TOTAL TIME 17.66 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.58
# estimated masks for 1 image(s) in 1.87 sec
# >>>> TOTAL TIME 1.87 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_8_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 5.81
# estimated masks for 1 image(s) in 6.10 sec
# >>>> TOTAL TIME 6.10 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 1.69
# estimated masks for 1 image(s) in 2.01 sec
# >>>> TOTAL TIME 2.01 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/DMSO_9_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 8.42
# estimated masks for 1 image(s) in 8.72 sec
# >>>> TOTAL TIME 8.72 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 1.83
# estimated masks for 1 image(s) in 2.13 sec
# >>>> TOTAL TIME 2.13 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_10_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 6.26
# estimated masks for 1 image(s) in 6.58 sec
# >>>> TOTAL TIME 6.58 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 1.65
# estimated masks for 1 image(s) in 1.96 sec
# >>>> TOTAL TIME 1.96 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_11_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 10.79
# estimated masks for 1 image(s) in 11.08 sec
# >>>> TOTAL TIME 11.08 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 1.58
# estimated masks for 1 image(s) in 1.86 sec
# >>>> TOTAL TIME 1.86 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_12_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 12.18
# estimated masks for 1 image(s) in 12.45 sec
# >>>> TOTAL TIME 12.45 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 1.50
# estimated masks for 1 image(s) in 1.81 sec
# >>>> TOTAL TIME 1.81 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_13_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 14.62
# estimated masks for 1 image(s) in 14.91 sec
# >>>> TOTAL TIME 14.91 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 2.13
# estimated masks for 1 image(s) in 2.43 sec
# >>>> TOTAL TIME 2.43 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_14_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 4.84
# estimated masks for 1 image(s) in 5.14 sec
# >>>> TOTAL TIME 5.14 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.64
# estimated masks for 1 image(s) in 1.93 sec
# >>>> TOTAL TIME 1.93 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_15_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 15.77
# estimated masks for 1 image(s) in 16.07 sec
# >>>> TOTAL TIME 16.07 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 2.13
# estimated masks for 1 image(s) in 2.42 sec
# >>>> TOTAL TIME 2.42 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_16_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 13.95
# estimated masks for 1 image(s) in 14.24 sec
# >>>> TOTAL TIME 14.24 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.89
# estimated masks for 1 image(s) in 2.18 sec
# >>>> TOTAL TIME 2.18 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_17_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 17.52
# estimated masks for 1 image(s) in 17.82 sec
# >>>> TOTAL TIME 17.82 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.70
# estimated masks for 1 image(s) in 2.00 sec
# >>>> TOTAL TIME 2.00 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_18_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 6.62
# estimated masks for 1 image(s) in 6.92 sec
# >>>> TOTAL TIME 6.92 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.29s; flow+mask computation 1.84
# estimated masks for 1 image(s) in 2.16 sec
# >>>> TOTAL TIME 2.16 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_19_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 11.62
# estimated masks for 1 image(s) in 11.92 sec
# >>>> TOTAL TIME 11.92 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.79
# estimated masks for 1 image(s) in 2.08 sec
# >>>> TOTAL TIME 2.08 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_1_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 3.14
# estimated masks for 1 image(s) in 3.45 sec
# >>>> TOTAL TIME 3.45 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.32
# estimated masks for 1 image(s) in 1.61 sec
# >>>> TOTAL TIME 1.61 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_20_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 5.92
# estimated masks for 1 image(s) in 6.21 sec
# >>>> TOTAL TIME 6.21 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 1.93
# estimated masks for 1 image(s) in 2.22 sec
# >>>> TOTAL TIME 2.22 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_2_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 10.77
# estimated masks for 1 image(s) in 11.06 sec
# >>>> TOTAL TIME 11.06 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.31s; flow+mask computation 1.44
# estimated masks for 1 image(s) in 1.78 sec
# >>>> TOTAL TIME 1.78 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_4_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.28s; flow+mask computation 5.58
# estimated masks for 1 image(s) in 5.91 sec
# >>>> TOTAL TIME 5.91 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.36
# estimated masks for 1 image(s) in 1.65 sec
# >>>> TOTAL TIME 1.65 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_5_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 37.09
# estimated masks for 1 image(s) in 37.38 sec
# >>>> TOTAL TIME 37.38 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.27s; flow+mask computation 2.21
# estimated masks for 1 image(s) in 2.51 sec
# >>>> TOTAL TIME 2.51 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_6_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.24s; flow+mask computation 3.92
# estimated masks for 1 image(s) in 4.20 sec
# >>>> TOTAL TIME 4.20 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.34
# estimated masks for 1 image(s) in 1.62 sec
# >>>> TOTAL TIME 1.62 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_7_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 5.36
# estimated masks for 1 image(s) in 5.65 sec
# >>>> TOTAL TIME 5.65 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.39
# estimated masks for 1 image(s) in 1.68 sec
# >>>> TOTAL TIME 1.68 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_8_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 17.83
# estimated masks for 1 image(s) in 18.13 sec
# >>>> TOTAL TIME 18.13 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.26s; flow+mask computation 1.73
# estimated masks for 1 image(s) in 2.02 sec
# >>>> TOTAL TIME 2.02 sec
# /home/tom/Documents/Scientifique/Thesis/Data/27X/271/max_projections/nutlin_9_MAX.tif
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.25s; flow+mask computation 8.27
# estimated masks for 1 image(s) in 8.56 sec
# >>>> TOTAL TIME 8.56 sec
# ** TORCH CUDA version installed and working. **
# >>>> using GPU
# processing 1 image(s)
# time spent: running network 0.29s; flow+mask computation 1.83
# estimated masks for 1 image(s) in 2.15 sec
# >>>> TOTAL TIME 2.15 sec

# %% [markdown]
# The sanity check will ensure all the nucleus are associated with the cell they are inside of. There are a couple of exclusion parameters in addition: cells that are more than 20 times smaller than the rest in the image will get excluded, and cell whose outline is more than 10% on the border of the image.
#
# DANGER: For now, this overwrites the outline files rather crudely. I'd advise making a copy of them, because if anything cause wrong, the original file might be gone.

# %%
sanitize.batch_sanity_check(root_folder,
                    exclude_border=True,
                    exclude_too_small=True,
                    reassign_nucleus=True)
# Out:
# nutlin_16_MAX_cytosol_cp_outlines.txt
# Cell 1 is +20x smaller than the rest and was excluded
# Cell 2 is +20x smaller than the rest and was excluded
# Cell 3 is +20x smaller than the rest and was excluded
# nutlin_1_MAX_cytosol_cp_outlines.txt
# nutlin_5_MAX_cytosol_cp_outlines.txt
# nutlin_7_MAX_cytosol_cp_outlines.txt
# Cell 1 is +10% on border and was excluded.
# Cell 2 has no nucleus inside and was excluded.
# nutlin_15_MAX_cytosol_cp_outlines.txt
# Cell 1 is +10% on border and was excluded.
# DMSO_11_MAX_cytosol_cp_outlines.txt
# nutlin_4_MAX_cytosol_cp_outlines.txt
# DMSO_2_MAX_cytosol_cp_outlines.txt
# Cell 2 is +20x smaller than the rest and was excluded
# Cell 4 is +20x smaller than the rest and was excluded
# Cell 5 is +20x smaller than the rest and was excluded
# nutlin_18_MAX_cytosol_cp_outlines.txt
# DMSO_8_MAX_cytosol_cp_outlines.txt
# nutlin_8_MAX_cytosol_cp_outlines.txt
# DMSO_12_MAX_cytosol_cp_outlines.txt
# DMSO_14_MAX_cytosol_cp_outlines.txt
# Cell 2 is +10% on border and was excluded.
# DMSO_19_MAX_cytosol_cp_outlines.txt
# nutlin_11_MAX_cytosol_cp_outlines.txt
# DMSO_6_MAX_cytosol_cp_outlines.txt
# Cell 2 is +20x smaller than the rest and was excluded
# Cell 3 is +20x smaller than the rest and was excluded
# Cell 4 is +20x smaller than the rest and was excluded
# nutlin_2_MAX_cytosol_cp_outlines.txt
# DMSO_4_MAX_cytosol_cp_outlines.txt
# Cell 3 is +20x smaller than the rest and was excluded
# Cell 4 is +20x smaller than the rest and was excluded
# Cell 5 is +20x smaller than the rest and was excluded
# Cell 6 is +20x smaller than the rest and was excluded
# Cell 7 is +20x smaller than the rest and was excluded
# DMSO_10_MAX_cytosol_cp_outlines.txt
# Cell 1 is +20x smaller than the rest and was excluded
# nutlin_10_MAX_cytosol_cp_outlines.txt
# nutlin_6_MAX_cytosol_cp_outlines.txt
# Cell 1 has no nucleus inside and was excluded.
# nutlin_14_MAX_cytosol_cp_outlines.txt
# DMSO_13_MAX_cytosol_cp_outlines.txt
# Cell 1 is +10% on border and was excluded.
# DMSO_17_MAX_cytosol_cp_outlines.txt
# nutlin_13_MAX_cytosol_cp_outlines.txt
# DMSO_15_MAX_cytosol_cp_outlines.txt
# nutlin_19_MAX_cytosol_cp_outlines.txt
# DMSO_9_MAX_cytosol_cp_outlines.txt
# nutlin_12_MAX_cytosol_cp_outlines.txt
# DMSO_20_MAX_cytosol_cp_outlines.txt
# DMSO_16_MAX_cytosol_cp_outlines.txt
# nutlin_9_MAX_cytosol_cp_outlines.txt
# DMSO_1_MAX_cytosol_cp_outlines.txt
# Cell 6 is +20x smaller than the rest and was excluded
# Cell 7 is +20x smaller than the rest and was excluded
# Cell 8 is +20x smaller than the rest and was excluded
# Cell 9 is +20x smaller than the rest and was excluded
# Cell 10 is +20x smaller than the rest and was excluded
# Cell 11 is +20x smaller than the rest and was excluded
# Cell 12 is +20x smaller than the rest and was excluded
# DMSO_5_MAX_cytosol_cp_outlines.txt
# DMSO_18_MAX_cytosol_cp_outlines.txt
# DMSO_3_MAX_cytosol_cp_outlines.txt
# DMSO_7_MAX_cytosol_cp_outlines.txt
# Cell 1 has no nucleus inside and was excluded.
# nutlin_20_MAX_cytosol_cp_outlines.txt
# Cell 2 is +20x smaller than the rest and was excluded
# Cell 3 is +20x smaller than the rest and was excluded
# Cell 4 is +20x smaller than the rest and was excluded
# Cell 5 is +20x smaller than the rest and was excluded
# Cell 6 is +20x smaller than the rest and was excluded
# Cell 7 is +20x smaller than the rest and was excluded
# Cell 8 is +20x smaller than the rest and was excluded
# nutlin_17_MAX_cytosol_cp_outlines.txt

# %% [markdown]
# The outline files can be loaded in ImageJ using the "imagej_roi_converter.py" macro provided in this folder.
#
#
# At this point we can generate the outline files compatible with FISHQuant.

# %%
seg.FQ_outlines_from_cp(root_folder)
